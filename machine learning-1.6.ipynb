# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('adult_income.csv', sep=',\s')
df.columns=['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race',
           'sex','capital_gain','capital_loss','hours_per_week','native_country','income']
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       50  Self-emp-not-inc   83311   Bachelors             13
# 1       38           Private  215646     HS-grad              9
# 2       53           Private  234721        11th              7
# 3       28           Private  338409   Bachelors             13
# 4       37           Private  284582     Masters             14
# ...    ...               ...     ...         ...            ...
# 32555   27           Private  257302  Assoc-acdm             12
# 32556   40           Private  154374     HS-grad              9
# 32557   58           Private  151910     HS-grad              9
# 32558   22           Private  201490     HS-grad              9
# 32559   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
#cheaking the null value
df.isnull().values.any()
# Out:
# False

# %% [raw]
# observation:
#     here we see there is no null value but thre is a '?' present in our dataset which is treated as null value.

# %%
#cheaking the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education_num   32560 non-null  int64
#  5   marital_status  32560 non-null  object
#  6   occupation      32560 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital_gain    32560 non-null  int64
#  11  capital_loss    32560 non-null  int64
#  12  hours_per_week  32560 non-null  int64
#  13  native_country  32560 non-null  object
#  14  income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [raw]
# observation:
# information of the dataset shows that there are no missing values.but in the dataset '?' is present,so i will
# encode '?' as nan value.

# %%
#replacing the question mark with nan 
df=df.replace('?',np.nan)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       50  Self-emp-not-inc   83311   Bachelors             13
# 1       38           Private  215646     HS-grad              9
# 2       53           Private  234721        11th              7
# 3       28           Private  338409   Bachelors             13
# 4       37           Private  284582     Masters             14
# ...    ...               ...     ...         ...            ...
# 32555   27           Private  257302  Assoc-acdm             12
# 32556   40           Private  154374     HS-grad              9
# 32557   58           Private  151910     HS-grad              9
# 32558   22           Private  201490     HS-grad              9
# 32559   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
#cheaking the null value again.
df.isnull().values.any()
# Out:
# True

# %% [raw]
# now it tells that nan value is present.
# now we cheak the number of nan values present in the particular columns.

# %%
#cheaking for null values
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %% [raw]
# observation:
#     1.there are 1836 null values present in the workclass columns.
#     2.1843 null value present in the occupation column.
#     3.583 null value present in native_country.
#
#
#     WE CAN SEE THESE VALUES VIA VISUALIZATION WITH THE HELP OF HEATMAP.

# %%
#cheaking null value via visualisation
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
#cheaking the information of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       30724 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education_num   32560 non-null  int64
#  5   marital_status  32560 non-null  object
#  6   occupation      30717 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital_gain    32560 non-null  int64
#  11  capital_loss    32560 non-null  int64
#  12  hours_per_week  32560 non-null  int64
#  13  native_country  31977 non-null  object
#  14  income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [raw]
# observation:
#     the summary shows that the variables-workclass,occupation,and native contry contain missing values.
#     all of the variables are catagorical data type. so,i will impute the missing values with the most frequent value i.e mode.

# %%
#imputing the missing values with mode
for col in ['workclass','occupation','native_country']:
    df[col].fillna(df[col].mode()[0],inplace=True)

# %%
#now again cheaking for missing values.
df.isnull().values.any()
# Out:
# False

# %% [raw]
# now our null values is removed.we can see it via visualization.

# %% [markdown]
# # NOW OUR DATA IS READY FOR VISUALIZATION WITHOUT ANY MISSING VALUES.

# %%
#putting the data in pandas dataframe
df_income=pd.DataFrame(df)
df_income.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   50  Self-emp-not-inc   83311  Bachelors             13
# 1   38           Private  215646    HS-grad              9
# 2   53           Private  234721       11th              7
# 3   28           Private  338409  Bachelors             13
# 4   37           Private  284582    Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              13  United-States  <=50K
# ...

# %%
#cheaking the various columns
df_income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
#cheaking the data type of the columns
df_income.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %% [raw]
# observation:
#
#     numeric_features=[age,fnlwgt,education_no,capital_gain,capital_loss,hours_per_week]
#     catagorical_features=[workclass,education,marital_status,occupation,relationship,race,sex,native_country,income]

# %% [markdown]
# FOR ANALYZING THE DATA WITH TARGET I.E INCOME WE HAVE TO CHANGE INCOME INTO NUMERIC TYPE.

# %%
#changing the data type of target variable
df_income['income'] = df_income['income'].map({'<=50k':0, '>50k':1})
df_income['income'].dtypes
# Out:
# dtype('float64')

# %%
df_income['income'].unique()
# Out:
# array([nan])

# %% [markdown]
# # summary statistics

# %%
df_income.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week  income
# count    32560.000000     0.0
# mean        40.437469     NaN
# std         12.347618     NaN
# min          1.000000     NaN
# 25%         40.000000     NaN
# 50%         40.000000     NaN
# 75%         45.000000     NaN
# ...

# %%
for column in df_income.columns:
    if df_income[column].dtype==object:
        print(str(column) + ':' + str(df_income[column].unique()))
        print('**********************************************************')
        print('\n')
# Out:
# workclass:['Self-emp-not-inc' 'Private' 'State-gov' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# **********************************************************
#
#
# education:['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# **********************************************************
#
#
# marital_status:['Married-civ-spouse' 'Divorced' 'Married-spouse-absent' 'Never-married'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# **********************************************************
#
#
# occupation:['Exec-managerial' 'Handlers-cleaners' 'Prof-specialty' 'Other-service'
#  'Adm-clerical' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# **********************************************************
#
#
# ...
